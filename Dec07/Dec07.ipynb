# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from scipy import stats

# %%
# import matplotlib
# matplotlib.rcParams.update({'font.size':18})
# matplotlib.rcParams.update({'font.family':'serif'})

# https://github.com/dhaitz/mplcyberpunk
import mplcyberpunk
plt.style.use("cyberpunk")

# %% [markdown]
# ## Puzzle 1

# %%
data = np.loadtxt('input.txt', delimiter=',', dtype=int)
print(data.size, data.min(), data.max())
# Out:
# 1000 0 1878

# %%
test = np.array([16,1,2,0,4,2,7,1,2,14])
max(test)
# Out:
# 16

# %%
np.median(test)
# Out:
# 2.0

# %%
# save fuel! compute fuel cost... simple enough
cost = np.arange(max(test))

for k in range(max(test)):
    print(k, np.sum(np.abs(test-k)))
    cost[k] = np.sum(np.abs(test-k))
plt.plot(cost)
# Out:
# 0 49
# 1 41
# 2 37
# 3 39
# 4 41
# 5 45
# 6 49
# 7 53
# 8 59
# 9 65
# 10 71
# 11 77
# 12 83
# 13 89
# 14 95
# 15 103
# <img src="data:image/png;base64,..." width="640">

# %%
# save fuel! compute fuel cost... simple enough
cost = np.arange(min(data), max(data)+1)

for k in range(min(data), max(data)+1):
#     print(k, np.sum(np.abs(test-k)))
    cost[k] = np.sum(np.abs(data-k))
plt.plot(cost)

print(min(cost))
# Out:
# <img src="data:image/png;base64,..." width="640">
# 349357

# %% [markdown]
# ## Puzzle 2

# %%
k=5
sum((np.abs(test-k)/2) * (1+np.abs(test-k)))
# Out:
# 168.0

# %%
# save fuel! compute fuel cost... squared fuel cost now
cost = np.arange(max(test))

for k in range(max(test)):
    # remember the old trick of adding consecutive numbers? 
    # I've never grok'd this, but i remember the lesson!
    #     (100 / 2)(1 + 100)
    print(k, np.sum((np.abs(test-k)/2) * (1+np.abs(test-k))))
    cost[k] = np.sum((np.abs(test-k)/2) * (1+np.abs(test-k)))
# plt.plot(cost)
# Out:
# 0 290.0
# 1 242.0
# 2 206.0
# 3 183.0
# 4 170.0
# 5 168.0
# 6 176.0
# 7 194.0
# 8 223.0
# 9 262.0
# 10 311.0
# 11 370.0
# 12 439.0
# 13 518.0
# 14 607.0
# 15 707.0

# %%
cost = np.arange(min(data), max(data)+1)

for k in range(min(data), max(data)+1):
    # remember the old trick of adding consecutive numbers? 
    # I've never grok'd this, but i remember the lesson!
    #     (100 / 2)(1 + 100)
    cost[k] = np.sum((np.abs(data-k)/2) * (1+np.abs(data-k)))
# plt.plot(cost)

# %%
print(min(cost))
# Out:
# 96708205

# %%
np.median(data)
# Out:
# 341.0
